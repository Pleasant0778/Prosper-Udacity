# %% [markdown]
# # Part II - (Presentation Title)
# ## by (Oluwaseyi Ogunlana)

# %% [markdown]
# ## Investigation Overview
#
#
# > The overall goal of this presentation if to analyse prosper financial dataset and find answer to the following questions.
#
# > what is the major purpose of getting loan from prosper?
# > What affects the borrower’s APR?
#
# > **Rubric Tip**: The key insights in the slideshow must match those documented in the README.md summary.
#
#
# ## Dataset Overview
#
# > Prosper is a San Francisco, California based company specializing in loans at low interest rates to the borrowers. For this project, we are using the data from the Posper to analyse it and trying to find the pattern in the Prosper data. This data set contains 113,937 loans with 81 variables on each loan.

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# suppress warnings from final output
import warnings
warnings.simplefilter("ignore")

base_color = sb.color_palette()[0]
# load in the dataset into a pandas dataframe
#reading the data and checking the first 5 rows in the data
loan_df = pd.read_csv('cleanprosper.csv')
loan_df.head()
# Out:
#        ListingCreationDate  Term LoanStatus               ClosedDate  \
# 0  2007-08-26 19:09:29.263    36  Completed  2009-08-14 00:00:00.000
# 1  2014-02-27 08:28:07.900    36    Current                      NaN
# 2  2007-01-05 15:00:47.090    36  Completed  2009-12-17 00:00:00.000
# 3  2012-10-22 11:02:35.010    36    Current                      NaN
# 4  2013-09-14 18:38:39.097    36    Current                      NaN
#
#    BorrowerAPR  BorrowerRate  LenderYield ProsperRating  ProsperScore  \
# 0      0.16516        0.1580       0.1380           NaN           NaN
# 1      0.12016        0.0920       0.0820             A           7.0
# 2      0.28269        0.2750       0.2400           NaN           NaN
# 3      0.12528        0.0974       0.0874             A           9.0
# 4      0.24614        0.2085       0.1985             D           4.0
#
#     ListingCategory  ...      LoanOriginationDate MonthlyLoanPayment  \
# 0     Not Available  ...  2007-09-12 00:00:00.000             330.43
# 1  Home Improvement  ...  2014-03-03 00:00:00.000             318.93
# 2     Not Available  ...  2007-01-17 00:00:00.000             123.32
# 3        Motorcycle  ...  2012-11-01 00:00:00.000             321.45
# 4  Home Improvement  ...  2013-09-20 00:00:00.000             563.97
#
#   LP_ServiceFees  Investors ListingCreationDate_year  \
# 0        -133.18        258                     2007
# 1           0.00          1                     2014
# 2         -24.20         41                     2007
# 3        -108.01        158                     2012
# 4         -60.27         20                     2013
#
#    ListingCreationDate_month  ClosedDate_year  ClosedDate_month  \
# 0                        Aug           2009.0               Aug
# 1                        Feb              NaN               NaN
# 2                        Jan           2009.0               Dec
# 3                        Oct              NaN               NaN
# 4                        Sep              NaN               NaN
#
#   LoanOriginationDate_year  LoanOriginationDate_month
# 0                     2007                        Sep
# 1                     2014                        Mar
# 2                     2007                        Jan
# 3                     2012                        Nov
# 4                     2013                        Sep
#
# [5 rows x 28 columns]

# %% [markdown]
# ## (Visualization 1)

# %%
plt.figure(figsize=(12,5))
loan_df['BorrowerState'].value_counts(normalize=True)[:10].sort_values().plot(kind='barh')
plt.title('Top 10 states of Prosper customer ')
plt.xlabel('Frequency (relative)')
plt.ylabel('BorrowerState')
plt.show()

# %% [markdown]
# # observation
#
# The state with hughest number o fprosper customer is Califonia

# %% [markdown]
# ## (Visualization 2)

# %%
sb.boxplot(y='LoanOriginalAmount', x= 'ListingCreationDate_year', data=loan_df, color=base_color)
plt.title('ListingCreationDate_year vs BorrowerAPR Distribution')
plt.xlabel('BorrowerAPR')
plt.ylabel('LoanOriginalAmount')
plt.show()

# %% [markdown]
# # observation
#
# Loan amount increases as the year increase i.e there has been increase loan request over the years

# %% [markdown]
# ## (Visualization 3)

# %%
plt.figure(figsize=(12,8))
sb.heatmap(loan_df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # observation
#
# There is a moderate relationship netween BorrowerAPR and closing year. moderate relationship alo exist between loan amount and stated monthly salary

# %% [markdown]
# # (Visualization 4)

# %%
plt.figure(figsize=(15,5))
sb.countplot(x='LoanStatus', hue='EmploymentStatus', data=loan_df, palette="Set1")
plt.legend(loc='upper right')
plt.xticks(rotation=90)
plt.title('Loan Status Grouped by Employmnet Status')
plt.xlabel('LoanStatus')
plt.ylabel('Frequency')
plt.show();

# %% [markdown]
# Observation
#
# Prosper customers that are employed have the higest running loan, followed by customer whose emplymnt status is not mentioned.
#
# It also worth noting yhat customer that are full-time emplyed defaulted than every other customers

# %% [markdown]
# ### Generate Slideshow
# Once you're ready to generate your slideshow, use the `jupyter nbconvert` command to generate the HTML slide show.

# %%
# Use this command if you are running this file in local
# !jupyter nbconvert Part_II_slide_deck_template.ipynb --to slides --post serve --no-input --no-prompt
# Out:
# [NbConvertApp] Converting notebook Part_II_slide_deck_template.ipynb to slides
# [NbConvertApp] Writing 802472 bytes to Part_II_slide_deck_template.slides.html
# [NbConvertApp] Redirecting reveal.js requests to https://cdnjs.cloudflare.com/ajax/libs/reveal.js/3.5.0
# Traceback (most recent call last):
#   File "C:\Users\Pleasant\Conda\Scripts\jupyter-nbconvert-script.py", line 10, in <module>
#     sys.exit(main())
#   File "C:\Users\Pleasant\Conda\lib\site-packages\jupyter_core\application.py", line 264, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "C:\Users\Pleasant\Conda\lib\site-packages\traitlets\config\application.py", line 846, in launch_instance
#     app.start()
#   File "C:\Users\Pleasant\Conda\lib\site-packages\nbconvert\nbconvertapp.py", line 346, in start
#     self.convert_notebooks()
#   File "C:\Users\Pleasant\Conda\lib\site-packages\nbconvert\nbconvertapp.py", line 518, in convert_notebooks
#     self.convert_single_notebook(notebook_filename)
#   File "C:\Users\Pleasant\Conda\lib\site-packages\nbconvert\nbconvertapp.py", line 485, in convert_single_notebook
#     self.postprocess_single_notebook(write_results)
#   File "C:\Users\Pleasant\Conda\lib\site-packages\nbconvert\nbconvertapp.py", line 457, in postprocess_single_notebook
#     self.postprocessor(write_results)
#   File "C:\Users\Pleasant\Conda\lib\site-packages\nbconvert\postprocessors\base.py", line 28, in __call__
#     self.postprocess(input)
#   File "C:\Users\Pleasant\Conda\lib\site-packages\nbconvert\postprocessors\serve.py", line 90, in postprocess
#     http_server.listen(self.port, address=self.ip)
#   File "C:\Users\Pleasant\Conda\lib\site-packages\tornado\tcpserver.py", line 151, in listen
#     sockets = bind_sockets(port, address=address)
#   File "C:\Users\Pleasant\Conda\lib\site-packages\tornado\netutil.py", line 161, in bind_sockets
#     sock.bind(sockaddr)
# OSError: [WinError 10048] Only one usage of each socket address (protocol/network address/port) is normally permitted
